# %%
# This file is only here for reference

from strands import Agent
from strands_tools import calculator

agent = Agent(tools=[calculator])
response = agent("What is 80/4")



# To check tokens used.

print(response.metrics.accumulated_usage['inputTokens'])
print(response.metrics.accumulated_usage['outputTokens'])
print(response.metrics.accumulated_usage['totalTokens'])

# %% [markdown]
# Attached below are the pre-built tools that comes with strands agent.
# Can see if we need use any of these
#
#
# ![image.png](attachment:image.png)

# %% [markdown]
# We can also steal TOOLs from mcp. Meaning we can give our Agent access to pre-built, commonly used tools in programming.
#
# (Dont mind my selfie on the right)
#
#
# ![](attachment:image.png)

# %% [markdown]
# Mini example of how ez a agent can be
#
#
#
# ![image.png](attachment:image.png)
